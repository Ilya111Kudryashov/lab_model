# %% [markdown]
# Выполнил студент группы М20-ИВТ-3
# Кудряшов Илья
#
# mtcnn
#
# dlib и deepface

# %%
# !pip install mtcnn

# %%
# !pip install deepface
# Out:
# ...
#      |████████████████████████████████| 61 kB 4.9 MB/s
# ...
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#   Created wheel for gdown: filename=gdown-4.2.0-py3-none-any.whl size=14273 sha256=d06ff22a61fd8283d9cfdd1709ebf7e3b652b834f59293c9dd3e96f45265adeb
#   Stored in directory: /root/.cache/pip/wheels/8c/17/ff/58721d1fabdb87c21a0529948cf39e2be9af90ddbe4ad65944
# Successfully built gdown
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 3.6.4
#     Uninstalling gdown-3.6.4:
#       Successfully uninstalled gdown-3.6.4
# ...

# %%
import mtcnn
# print version
print(mtcnn.__version__)
# Out:
# 0.1.0

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
from deepface import DeepFace
import cv2
import pandas as pd
import matplotlib.pyplot as plt
from keras.preprocessing import image
import numpy as np
from matplotlib.pyplot import imshow
import matplotlib.pyplot as plt
import matplotlib
from skimage import io
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
# !ls /content/drive/MyDrive
# Out:
#  1.jpg			  mobilenet_1_0_224_tf_no_top.h5   test.csv
#  blue_tit.jpg		  MobileNetV1.ipynb		   test.csv.zip
# 'Colab Notebooks'	  poodle1.jpg			   test_directory1
#  downloads		  README.rst			   train.csv
#  German_Shepherd.jpg	  requirements.txt		   train.csv.zip
#  google_images_download   sample_submission.csv		   Untitled0.ipynb
#  labrador1.jpg		  sample_submission.csv.zip	  'Без названия'
#  Licence.txt		  setup.cfg
#  MANIFEST.in		  setup.py

# %%
img1_path = "/content/drive/My Drive/1.jpg" 
img2_path = "/content/drive/My Drive/2.jpg" 
img3_path = "/content/drive/My Drive/3.jpg" 
img4_path = "/content/drive/My Drive/4.jpg" 
img5_path = "/content/drive/My Drive/5.jpg" 
img6_path = "/content/drive/My Drive/6.jpg"

# %%
orig = cv2.imread(img1_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img1_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
orig = cv2.imread(img2_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img2_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-d05a8b0d5687> in <module>()
# ----> 1 detected_face = DeepFace.detectFace(img2_path, detector_backend = 'dlib')
#       2 plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in detectFace(img_path, detector_backend, enforce_detection, align)
#     812
#     813 	img = functions.preprocess_face(img = img_path, detector_backend = detector_backend
# --> 814 		, enforce_detection = enforce_detection, align = align)[0] #preprocess_face returns (1, 224, 224, 3)
#     815         return img[:, :, ::-1] #bgr to rgb
#     816
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
# ...

# %%
orig = cv2.imread(img3_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img3_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-37-8dc60d144d09> in <module>()
# ----> 1 detected_face = DeepFace.detectFace(img3_path, detector_backend = 'dlib')
#       2 plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in detectFace(img_path, detector_backend, enforce_detection, align)
#     812
#     813 	img = functions.preprocess_face(img = img_path, detector_backend = detector_backend
# --> 814 		, enforce_detection = enforce_detection, align = align)[0] #preprocess_face returns (1, 224, 224, 3)
#     815         return img[:, :, ::-1] #bgr to rgb
#     816
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
# ...

# %%
orig = cv2.imread(img4_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img4_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-42-9ec35ed63193> in <module>()
# ----> 1 detected_face = DeepFace.detectFace(img4_path, detector_backend = 'dlib')
#       2 plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in detectFace(img_path, detector_backend, enforce_detection, align)
#     812
#     813 	img = functions.preprocess_face(img = img_path, detector_backend = detector_backend
# --> 814 		, enforce_detection = enforce_detection, align = align)[0] #preprocess_face returns (1, 224, 224, 3)
#     815         return img[:, :, ::-1] #bgr to rgb
#     816
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
# ...

# %%
orig = cv2.imread(img5_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img5_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
orig = cv2.imread(img6_path)
plt.imshow(cv2.cvtColor(orig, cv2.COLOR_BGR2RGB))

# %%
detected_face = DeepFace.detectFace(img6_path, detector_backend = 'mtcnn')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица

# %%
detected_face = DeepFace.detectFace(img6_path, detector_backend = 'dlib')
plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-47-6af7b7ef6d3d> in <module>()
# ----> 1 detected_face = DeepFace.detectFace(img6_path, detector_backend = 'dlib')
#       2 plt.imshow(cv2.cvtColor(detected_face, cv2.COLOR_BGR2RGB)) #обнаружение лица
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in detectFace(img_path, detector_backend, enforce_detection, align)
#     812
#     813 	img = functions.preprocess_face(img = img_path, detector_backend = detector_backend
# --> 814 		, enforce_detection = enforce_detection, align = align)[0] #preprocess_face returns (1, 224, 224, 3)
#     815         return img[:, :, ::-1] #bgr to rgb
#     816
#
# /usr/local/lib/python3.7/dist-packages/deepface/commons/functions.py in preprocess_face(img, target_size, grayscale, enforce_detection, detector_backend, return_region, align)
# ...

# %%
result = DeepFace.verify(img1_path, img2_path, model_name='DeepFace', detector_backend = 'mtcnn')
print( result["verified"])
# Out:
# False

# %%
result
# Out:
# {'distance': 0.4543468470312675,
#  'max_threshold_to_verify': 0.23,
#  'model': 'DeepFace',
#  'similarity_metric': 'cosine',
#  'verified': False}

# %%
analysis = DeepFace.analyze(img1_path, actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# facial_expression_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/facial_expression_model_weights.h5
# To: /root/.deepface/weights/facial_expression_model_weights.h5
# 100%|██████████| 5.98M/5.98M [00:00<00:00, 86.4MB/s]
# age_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/age_model_weights.h5
# To: /root/.deepface/weights/age_model_weights.h5
# 100%|██████████| 539M/539M [00:33<00:00, 16.1MB/s]
# gender_model_weights.h5 will be downloaded...
# Downloading...
# From: https://github.com/serengil/deepface_models/releases/download/v1.0/gender_model_weights.h5
# To: /root/.deepface/weights/gender_model_weights.h5
# 100%|██████████| 537M/537M [00:50<00:00, 10.7MB/s]
# race_model_single_batch.h5 will be downloaded...
# Downloading...
# ...

# %%
analysis = DeepFace.analyze(img2_path, actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# Action: age:   0%|          | 0/4 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-52-22710492c986> in <module>()
# ----> 1 analysis = DeepFace.analyze(img2_path, actions = ["age", "gender", "emotion", "race"])
#       2 print(analysis)
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     402                         elif action == 'age':
#     403                                 if img_224 is None:
# --> 404                                         img_224, region = functions.preprocess_face(img = img_path, target_size = (224, 224), grayscale = False, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     405
# ...

# %%
analysis = DeepFace.analyze(img3_path, actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# Action: age:   0%|          | 0/4 [00:01<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-53-74ca75e237b7> in <module>()
# ----> 1 analysis = DeepFace.analyze(img3_path, actions = ["age", "gender", "emotion", "race"])
#       2 print(analysis)
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     402                         elif action == 'age':
#     403                                 if img_224 is None:
# --> 404                                         img_224, region = functions.preprocess_face(img = img_path, target_size = (224, 224), grayscale = False, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     405
# ...

# %%
analysis = DeepFace.analyze(img4_path, actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# Action: age:   0%|          | 0/4 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-54-f6396b636e0a> in <module>()
# ----> 1 analysis = DeepFace.analyze(img4_path, actions = ["age", "gender", "emotion", "race"])
#       2 print(analysis)
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in analyze(img_path, actions, models, enforce_detection, detector_backend, prog_bar)
#     402                         elif action == 'age':
#     403                                 if img_224 is None:
# --> 404                                         img_224, region = functions.preprocess_face(img = img_path, target_size = (224, 224), grayscale = False, enforce_detection = enforce_detection, detector_backend = detector_backend, return_region = True)
#     405
# ...

# %%
analysis = DeepFace.analyze(img6_path, actions = ["age", "gender", "emotion", "race"])
print(analysis)
# Out:
# Action: race: 100%|██████████| 4/4 [00:05<00:00,  1.29s/it]
# {'age': 36, 'region': {'x': 125, 'y': 383, 'w': 62, 'h': 62}, 'gender': 'Man', 'emotion': {'angry': 18.3847114443779, 'disgust': 0.0035759949241764843, 'fear': 5.703896656632423, 'happy': 0.09758686646819115, 'sad': 42.25282073020935, 'surprise': 0.00019332235297042644, 'neutral': 33.55721831321716}, 'dominant_emotion': 'sad', 'race': {'asian': 6.110782565381221, 'indian': 12.189838327188692, 'black': 4.482276948418981, 'white': 31.898226511689842, 'middle eastern': 34.097893941653496, 'latino hispanic': 11.220973882559075}, 'dominant_race': 'middle eastern'}

# %%
result = DeepFace.verify(img1_path, img3_path, model_name='DeepFace', detector_backend = 'dlib')
print( result["verified"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-57-430f06c973b5> in <module>()
# ----> 1 result = DeepFace.verify(img1_path, img3_path, model_name='DeepFace', detector_backend = 'dlib')
#       2 print( result["verified"])
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in verify(img1_path, img2_path, model_name, distance_metric, model, enforce_detection, detector_backend, align, prog_bar, normalization)
#     170                                                 , enforce_detection = enforce_detection, detector_backend = detector_backend
#     171                                                 , align = align
# --> 172                                                 , normalization = normalization
#     173 						)
#     174
#
# ...

# %%
result = DeepFace.verify(img1_path, img3_path, model_name='DeepFace', detector_backend = 'mtcnn')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img4_path, model_name='DeepFace', detector_backend = 'dlib')
print( result["verified"])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-60-2b6ab2762efc> in <module>()
# ----> 1 result = DeepFace.verify(img1_path, img4_path, model_name='DeepFace', detector_backend = 'dlib')
#       2 print( result["verified"])
#
# /usr/local/lib/python3.7/dist-packages/deepface/DeepFace.py in verify(img1_path, img2_path, model_name, distance_metric, model, enforce_detection, detector_backend, align, prog_bar, normalization)
#     170                                                 , enforce_detection = enforce_detection, detector_backend = detector_backend
#     171                                                 , align = align
# --> 172                                                 , normalization = normalization
#     173 						)
#     174
#
# ...

# %%
result = DeepFace.verify(img1_path, img4_path, model_name='DeepFace', detector_backend = 'mtcnn')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img5_path, model_name='DeepFace', detector_backend = 'mtcnn')
print( result["verified"])
# Out:
# False

# %%
result = DeepFace.verify(img1_path, img6_path, model_name='DeepFace', detector_backend = 'mtcnn')
print( result["verified"])
# Out:
# False
